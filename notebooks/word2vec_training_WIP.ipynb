# %%
import pandas as pd
import numpy as np
from gensim.models import Word2Vec

from pandas.core.common import flatten
import nltk

from tqdm import tqdm

# %%
orders = pd.read_csv("data/orders.csv")

# %%
# Limiting the number of orders to process
orders_limit = 10000
# Color constants for the console
COLOR_CONSTANT = {'input': '\033[94m', 'warning': '\033[93m', 'error': '\033[91m', 'note': '\033[96m', 'end': '\033[0m'}
# Number of orders/baskets to pull similar to the requested
orders_returns = 15
# Number of dimensions of the vector annoy is going to store. 
vector_size = 25
# Number of trees for queries. When making a query the more trees the easier it is to go down the right path. 
trees = 10
# Number of product recommendation as maximum
#NUMBER_OUTPUT_PRODUCTS = 10
# Sample size for the TSNE model and plot
tsne_size = 1000
# Threshold for a minimum support
threshold = 1e-3
# Threshold for the maximun number of products to bring
threshold_top = 10
# Threshold for distance, based on the quantile calculation of the basket distances
threshold_distance= 0.1

# %%
products = pd.read_csv("data/products.csv")
products['product_name'] = products.product_name.str.lower()
product_dict = dict(zip(products.product_id, products.product_name))

# %%
products['products_mod'] = products['product_name'].str.lower()
# Clean special characters.
products['products_mod'] = products['products_mod'].str.replace('\W', ' ', regex=True)
# Split products into terms: Tokenize.
products['products_mod'] = products['products_mod'].str.split()

# Merge the department and aisle names into the dataframe. 
products = pd.merge(products, departments, on="department_id", how='outer')
products = pd.merge(products, aisles, on="aisle_id", how='outer')

# Remove synonyms here in the list
products['products_mod'] = products[['products_mod', 'aisle', 'department']].values.tolist()
products['products_mod'] = products['products_mod'].apply(lambda x:list(flatten(x)))

# %%
# Steam and lemmatisation of the product name
# https://stackoverflow.com/a/25082458/3780957
# https://en.wikipedia.org/wiki/Lemmatisation

lemma = nltk.wordnet.WordNetLemmatizer()
sno = nltk.stem.SnowballStemmer('english')
products['products_lemma'] = products['products_mod'].apply(lambda row:[lemma.lemmatize(item) for item in row])
products['products_lemma'] = products['products_lemma'].apply(lambda row:[sno.stem(item) for item in row])

# %%
products.loc[0, ['products_lemma', 'products_mod']]
# Out:
# products_lemma        [chocol, sandwich, cooki, cookies cak, snack]
# products_mod      [chocolate, sandwich, cookies, cookies cakes, ...
# Name: 0, dtype: object

# %%
products
# Out:
#        product_id                                       product_name  \
# 0               1                         chocolate sandwich cookies
# 1              78                  nutter butter cookie bites go-pak
# 2             102                              danish butter cookies
# 3             172     gluten free all natural chocolate chip cookies
# 4             285                       mini nilla wafers munch pack
# ...           ...                                                ...
# 49683       22827                         organic black mission figs
# 49684       28655                         crystallized ginger chunks
# 49685       30365                                    vegetable chips
# 49686       38007                     naturally sweet plantain chips
# 49687       48778  fit super a juice, cold pressed, carrot/apple/...
#
#        aisle_id  department_id  \
# 0            61             19
# 1            61             19
# 2            61             19
# 3            61             19
# 4            61             19
# ...         ...            ...
# 49683        18             10
# 49684        18             10
# 49685        18             10
# 49686        18             10
# 49687        18             10
#
#                                             products_mod department  \
# 0      [chocolate, sandwich, cookies, cookies cakes, ...     snacks
# 1      [nutter, butter, cookie, bites, go, pak, cooki...     snacks
# 2       [danish, butter, cookies, cookies cakes, snacks]     snacks
# 3      [gluten, free, all, natural, chocolate, chip, ...     snacks
# 4      [mini, nilla, wafers, munch, pack, cookies cak...     snacks
# ...                                                  ...        ...
# 49683  [organic, black, mission, figs, bulk dried fru...       bulk
# 49684  [crystallized, ginger, chunks, bulk dried frui...       bulk
# 49685  [vegetable, chips, bulk dried fruits vegetable...       bulk
# 49686  [naturally, sweet, plantain, chips, bulk dried...       bulk
# 49687  [fit, super, a, juice, cold, pressed, carrot, ...       bulk
#
#                               aisle  \
# 0                     cookies cakes
# 1                     cookies cakes
# 2                     cookies cakes
# 3                     cookies cakes
# 4                     cookies cakes
# ...                             ...
# 49683  bulk dried fruits vegetables
# 49684  bulk dried fruits vegetables
# 49685  bulk dried fruits vegetables
# 49686  bulk dried fruits vegetables
# 49687  bulk dried fruits vegetables
#
#                                           products_lemma  \
# 0          [chocol, sandwich, cooki, cookies cak, snack]
# 1      [nutter, butter, cooki, bite, go, pak, cookies...
# 2            [danish, butter, cooki, cookies cak, snack]
# 3      [gluten, free, all, natur, chocol, chip, cooki...
# 4      [mini, nilla, wafer, munch, pack, cookies cak,...
# ...                                                  ...
# 49683  [organ, black, mission, fig, bulk dried fruits...
# 49684  [crystal, ginger, chunk, bulk dried fruits veg...
# 49685       [veget, chip, bulk dried fruits veget, bulk]
# 49686  [natur, sweet, plantain, chip, bulk dried frui...
# 49687  [fit, super, a, juic, cold, press, carrot, app...
#
#                                                  vectors
# 0      [0.0048274104, -0.000982171, 0.0135972, 0.0127...
# 1      [0.00053272134, -0.0016033737, 0.010740572, 0....
# 2      [0.007038258, -0.005356223, 0.013606298, 0.012...
# 3      [0.0021328337, 0.0015880795, 0.003318248, 0.00...
# 4      [0.0013800311, -0.0027976793, 0.014260448, 0.0...
# ...                                                  ...
# 49683  [0.0052806833, -0.00082850707, -0.00867612, -0...
# 49684  [-0.001904256, -0.002966276, -0.010072536, -0....
# 49685  [-0.01041863, -0.012444427, -0.016481701, -0.0...
# 49686  [0.0021803195, -0.00030821623, -0.011328056, -...
# 49687  [0.004454585, -0.010760515, -0.0068090972, 0.0...
#
# [49688 rows x 9 columns]

# %%
## Training the `Word2Vec` model
# The `Word2Vec` model is a shallow neural network that is trained to reconstruct linguistic contexts of words. <br>
# The model takes as input a large corpus of text and produces a vector space, typically of several hundred dimensions, with each unique word in the corpus being assigned a corresponding vector in the space. <br>
# Word vectors are positioned in the vector space such that words that share common contexts in the corpus are located in close proximity to one another in the space. <br>
# The model is trained by taking each sentence in the corpus, sliding a window of fixed size over it and trying to predict the word in the middle of the window, given the words on the sides of the window as input. <br>

# Defining the maximun window
window_max = max(products['products_lemma'].apply(lambda x:len(x)))

# size=20: In order to make `Word2Vec` a little bit quicker and for memory efficiency we're going to use 20 dimensions.
# window=49: In order to make sure all words are used in training the model, we're going to set a large.
w2vec_model = Word2Vec(list(products['products_lemma']), vector_size=vector_size, window=window_max, min_count=1, workers=-1)

### Vector calculation for products
# Loop through each product and obtain the average of each string that makes a product. <br>
# This will be the vector representation of the product. <br>
# The vector representation of the product will be used to calculate the similarity between products. <br>
# The similarity between products will be used to recommend products to the user. <br>

# Loop through each word in the product name to generate the vector.
prods_w2v = dict()
for row, product in tqdm(products.iterrows()):
    word_vector = list()
    for word in product['products_lemma']:
        word_vector.append(w2vec_model.wv[word])

    prods_w2v[product['product_id']] = np.average(word_vector, axis=0)

# Save vector values in list form to the dataframe.
products['vectors'] = prods_w2v.values()
# Out:
# 49688it [00:01, 30440.11it/s]

# %%
products
# Out:
#        product_id                                       product_name  \
# 0               1                         chocolate sandwich cookies
# 1              78                  nutter butter cookie bites go-pak
# 2             102                              danish butter cookies
# 3             172     gluten free all natural chocolate chip cookies
# 4             285                       mini nilla wafers munch pack
# ...           ...                                                ...
# 49683       22827                         organic black mission figs
# 49684       28655                         crystallized ginger chunks
# 49685       30365                                    vegetable chips
# 49686       38007                     naturally sweet plantain chips
# 49687       48778  fit super a juice, cold pressed, carrot/apple/...
#
#        aisle_id  department_id  \
# 0            61             19
# 1            61             19
# 2            61             19
# 3            61             19
# 4            61             19
# ...         ...            ...
# 49683        18             10
# 49684        18             10
# 49685        18             10
# 49686        18             10
# 49687        18             10
#
#                                             products_mod department  \
# 0      [chocolate, sandwich, cookies, cookies cakes, ...     snacks
# 1      [nutter, butter, cookie, bites, go, pak, cooki...     snacks
# 2       [danish, butter, cookies, cookies cakes, snacks]     snacks
# 3      [gluten, free, all, natural, chocolate, chip, ...     snacks
# 4      [mini, nilla, wafers, munch, pack, cookies cak...     snacks
# ...                                                  ...        ...
# 49683  [organic, black, mission, figs, bulk dried fru...       bulk
# 49684  [crystallized, ginger, chunks, bulk dried frui...       bulk
# 49685  [vegetable, chips, bulk dried fruits vegetable...       bulk
# 49686  [naturally, sweet, plantain, chips, bulk dried...       bulk
# 49687  [fit, super, a, juice, cold, pressed, carrot, ...       bulk
#
#                               aisle  \
# 0                     cookies cakes
# 1                     cookies cakes
# 2                     cookies cakes
# 3                     cookies cakes
# 4                     cookies cakes
# ...                             ...
# 49683  bulk dried fruits vegetables
# 49684  bulk dried fruits vegetables
# 49685  bulk dried fruits vegetables
# 49686  bulk dried fruits vegetables
# 49687  bulk dried fruits vegetables
#
#                                           products_lemma  \
# 0          [chocol, sandwich, cooki, cookies cak, snack]
# 1      [nutter, butter, cooki, bite, go, pak, cookies...
# 2            [danish, butter, cooki, cookies cak, snack]
# 3      [gluten, free, all, natur, chocol, chip, cooki...
# 4      [mini, nilla, wafer, munch, pack, cookies cak,...
# ...                                                  ...
# 49683  [organ, black, mission, fig, bulk dried fruits...
# 49684  [crystal, ginger, chunk, bulk dried fruits veg...
# 49685       [veget, chip, bulk dried fruits veget, bulk]
# 49686  [natur, sweet, plantain, chip, bulk dried frui...
# 49687  [fit, super, a, juic, cold, press, carrot, app...
#
#                                                  vectors
# 0      [0.0048274104, -0.000982171, 0.0135972, 0.0127...
# 1      [0.00053272134, -0.0016033737, 0.010740572, 0....
# 2      [0.007038258, -0.005356223, 0.013606298, 0.012...
# 3      [0.0021328337, 0.0015880795, 0.003318248, 0.00...
# 4      [0.0013800311, -0.0027976793, 0.014260448, 0.0...
# ...                                                  ...
# 49683  [0.0052806833, -0.00082850707, -0.00867612, -0...
# 49684  [-0.001904256, -0.002966276, -0.010072536, -0....
# 49685  [-0.01041863, -0.012444427, -0.016481701, -0.0...
# 49686  [0.0021803195, -0.00030821623, -0.011328056, -...
# 49687  [0.004454585, -0.010760515, -0.0068090972, 0.0...
#
# [49688 rows x 9 columns]

# %%
train_orders = pd.read_csv("data/order_products__train.csv")
prior_orders = pd.read_csv("data/order_products__prior.csv")

# %%
train_orders.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         1       49302                  1          1
# 1         1       11109                  2          1
# 2         1       10246                  3          0
# 3         1       49683                  4          0
# 4         1       43633                  5          1

# %%
prior_orders.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
order_df = pd.concat([train_orders, prior_orders])
order_df = order_df.merge(products[['product_id', 'product_name']], on='product_id', how='left')

# %%
data = order_df.groupby('order_id').apply(lambda order:order['product_name'].tolist())
data_arr = data.values

# %%
# %%time
sentence_df = order_df.groupby('order_id').apply(lambda order:order['product_id'].tolist())
sentence = sentence_df.values
# Out:
# CPU times: user 1min 3s, sys: 32.7 s, total: 1min 35s
# Wall time: 1min 59s

# %%
longest = np.max(sentence_df.apply(len))

# %%
# %%time
model = gensim.models.Word2Vec(sentence, vector_size=128, window=longest, min_count=2, workers = 4)

# %%
vocab = list(model.wv.key_to_index.keys())

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
pca.fit(model.wv.vectors)
# Out:
# PCA(n_components=2)

# %%
# data.sample(5)

# %%
# [i for i in data_arr if "organic marinara pasta sauce" in i]

# %%
import random

# %%
pid = random.randrange(1,max(vocab))
pname = product_dict[pid]
print(pname)

similar = model.wv.most_similar(positive=pid, topn=10)
[(product_dict[i[0]], i[1]) for i in similar]
# Out:
# teriyaki chicken
# [('mozzarella sticks', 0.8877257704734802),
#  ('grilled chicken taquitos', 0.870657205581665),
#  ('chicken enchilada casserole', 0.8661288619041443),
#  ('pear halves', 0.8410782814025879),
#  ('smoked pulled pork', 0.8347561359405518),
#  ('petite dill pickles', 0.828694224357605),
#  ('honey bbq glazed chicken wings', 0.8267912864685059),
#  ('omeprazole acid reducer tablets', 0.8219950795173645),
#  ('flame grilled beef patty', 0.8219634294509888),
#  ('double chocolate muffins', 0.8195507526397705)]

# %%
model.wv.save("word2vec.wordvectors")

# %%
l = [i for i in data if 'teriyaki chicken' in i]

# %%
product_dict[i[0]]
# Out:
# 'light and lean mattar paneer'

# %%
l
# Out:
# [['fat free milk',
#   'seedless cucumbers',
#   'bag of organic bananas',
#   'shredded mexican blend cheese',
#   'organic whole milk yogurt',
#   'raw shrimp',
#   'orange juice',
#   'beef hot dogs',
#   'teriyaki chicken'],
#  ['small curd lowfat 2% milkfat cottage cheese', 'teriyaki chicken'],
#  ['extralean ground turkey breast',
#   'diet pepsi pack',
#   'diet iced tea',
#   'ready rice  pilaf',
#   'ready rice roasted chicken flavored',
#   'trop50 no pulp orange juice w/ calcium + vitamin d, 50% less sugar & calories',
#   'shrimp & vegetable stir fry',
#   'steamfresh premium selects broccoli florets',
#   'deli counter turkey breast',
#   "chef's favorites lightly seasoned asian medley",
#   'teriyaki chicken'],
#  ['boneless & skinless chicken breasts',
#   'teriyaki chicken',
#   'pineapple chunks',
#   'organic crimini mushrooms'],
#  ['organic baby spinach',
#   'bag of organic bananas',
#   'usda aa extra large eggs',
#   'celery sticks',
#   'shredded parmigiano reggiano',
#   'teriyaki & pineapple chicken meatballs',
#   'teriyaki chicken',
#   'cherrios honey nut'],
#  ['reduced fat 2% milk',
#   'organic strawberries',
#   'bag of organic bananas',
#   'small curd lowfat 2% milkfat cottage cheese',
#   'split top wheat bread',
#   'teriyaki chicken',
#   'cherrios honey nut',
#   '0% greek strained yogurt',
#   'pepproni pockets'],
#  ['sweet kale salad mix', 'teriyaki chicken', 'seedless watermelon'],
#  ['organic fudge bars',
#   'teriyaki chicken',
#   'creamy peanut butter',
#   'mini seedless watermelon pack'],
#  ['bag of organic bananas',
#   'organic whole milk',
#   'evaporated milk,',
#   'veggie cheese & pretzel snack pac prepacked',
#   'dried tart cherries',
#   'teriyaki chicken',
#   'raspberries',
#   'organic sliced mushrooms',
#   'imported sardines in pure olive oil skinless & boneless salt added',
#   'bolani spinach filled flatbread',
#   'lobster bisque',
#   'oranges'],
#  ['sweet whole gherkins',
#   'white meat chicken taquitos',
#   'teriyaki chicken',
#   'rice pilaf',
#   'cranberry walnut salad cafe bowl',
#   'bistro bowl chicken caesar salad'],
#  ['sea salt brown rice crackers',
#   'organic spinach and cheese ravioli',
#   'whole grain cheddar baked snack crackers',
#   'organic lentil vegetable soup',
#   'teriyaki chicken',
#   'pitted kalamata olives',
#   'seedless cucumbers',
#   'cheez-it cheddar cracker'],
#  ['soda',
#   'teriyaki chicken',
#   'bag of organic bananas',
#   'baby cucumbers',
#   'strawberries',
#   'butter lettuce',
#   'country french bread',
#   'homogenized milk'],
#  ['red berry vodka', 'diet soda', 'teriyaki chicken'],
#  ['bag of organic bananas',
#   'shredded mexican blend cheese',
#   'bunny-luv organic carrots',
#   'teriyaki chicken',
#   'pretzel slider buns'],
#  ['frosted mini-wheats original cereal',
#   'fat free blueberry yogurt',
#   'organic iceberg lettuce',
#   'raisin bran cereal',
#   'honey nut cheerios',
#   'traditional medium roast coffee',
#   'vanilla milk chocolate ice cream bars',
#   'vanilla ice cream sandwiches',
#   'teriyaki chicken bowl',
#   'chicken fried rice',
#   'teriyaki chicken',
#   'original nooks & crannies english muffins',
#   'reduced-fat soft cream cheese',
#   'organic large grade aa omega-3 eggs',
#   'cucumber kirby',
#   'ritz crackers',
#   'toasted cheddar ritz chips',
#   'cherubs heavenly salad tomatoes',
#   'chicken breast tenders',
#   'vanilla milk chocolate almond ice cream bars',
#   'organic bread with 21 whole grains',
#   'sharp cheddar cheese',
#   'light sour cream',
#   'green bell pepper',
#   'organic white mushrooms',
#   'organic hass avocado'],
#  ['strawberries',
#   'hass avocados',
#   'soda',
#   'teriyaki chicken',
#   'pierogi potato & cheese',
#   'club delight sausage, egg, & cheese sandwiches',
#   'low sodium bacon',
#   'raw shrimp'],
#  ['high-traffic foam large area carpet cleaner',
#   'mini spaghetti & meatballs',
#   '100% whole wheat flour tortillas',
#   'teriyaki chicken',
#   'original crunchy corn snack'],
#  ['organic romaine hearts',
#   'sprouted multi-grain bread',
#   'chicken florentine & farfalle pasta',
#   'boneless skinless chicken breasts',
#   'teriyaki chicken'],
#  ['cranberry almond chicken salad', 'teriyaki chicken', 'organic fuji apples'],
#  ['wheat thins original',
#   'organic 2% chocolate milk',
#   'bag of organic bananas',
#   'teriyaki chicken',
#   'organic green beans'],
#  ['lemon-lime 12 pack soda',
#   '2% reduced fat milk',
#   'pizzeria-style crust supreme speciale pizza',
#   'shredded sharp cheddar cheese',
#   'french vanilla creamer',
#   'light mozarella string cheese',
#   'sweet rolls',
#   'apple juice',
#   'low fat chocolate milk',
#   'italian dry salame',
#   'sweet apple slices',
#   'cherubs heavenly salad tomatoes',
#   'hazelnut spread with skim milk & cocoa',
#   'jasmine ready rice',
#   'dinner plates',
#   'ultra soft bath tissue',
#   'smooth ranch dip',
#   'cage free brown eggs-large, grade a',
#   'orange chicken',
#   'real aged cheddar macaroni & cheese',
#   'paper towels white w/ thirst pockets',
#   'original body wash',
#   'crunchy breaded fish fillets',
#   'cherrios honey nut',
#   'pico de gallo',
#   'spring water antibacterial liquid hand soap with moisturizer',
#   'apple apple applesauce on the go pouches',
#   'mixed fruit fruit snacks',
#   'dry roasted lightly salted edamame',
#   'original salt-free seasoning blend',
#   'teriyaki chicken',
#   'fresh cut green beans',
#   'french style fresh cut green beans',
#   'whole baby corn',
#   'whole berry cranberry sauce',
#   'chicken broth',
#   'organic blackberries',
#   'head-to-toe baby wash',
#   'vitamin e moisture rich shampoo for dry or damaged hair',
#   'circus animal cookies',
#   'goldfish baked snack crackers variety pack',
#   'organic blue corn tortilla chips'],
#  ['grilled chicken taquitos', 'teriyaki chicken'],
#  ['fully husked & trimmed super sweet corn',
#   'rainbow bell peppers',
#   'organic medium salsa',
#   'drinking water',
#   'strawberries',
#   'pure irish butter',
#   'raspberries',
#   'organic baby carrots',
#   'bag of organic bananas',
#   'honeycrisp apples',
#   'organic strawberries',
#   'marinara sauce',
#   'baby cucumbers',
#   'popcorn',
#   'cherrios honey nut',
#   'pain relief tablets',
#   'shredded parmigiano reggiano',
#   'organic tortilla chips',
#   'teriyaki chicken',
#   'cinnamon toast crunch',
#   'mozzarella cheese',
#   'butter bread'],
#  ['teriyaki chicken'],
#  ['seedless small watermelon',
#   'hass avocados',
#   'strawberries',
#   'red seedless grapes',
#   'organic 2% milk',
#   'green seedless grapes',
#   'alaskan salmon burgers',
#   'solid white albacore tuna',
#   '100% grated parmesan cheese',
#   'sesame bagels',
#   'honeydew melon',
#   'teriyaki chicken',
#   'smoked pulled pork'],
#  ['corn flakes',
#   'unsalted butter',
#   'strawberry ice cream',
#   'original cream cheese',
#   'apple juice',
#   'oral electrolyte solution mixed fruit',
#   'unflavored oral electrolyte solution',
#   'variety pack',
#   'tonic water',
#   'split top white bread',
#   'garlic bread',
#   'bread, jewish rye',
#   'english muffins',
#   'plain bagels',
#   'classic dinner rolls',
#   'crispy sauerkraut',
#   'frozen banana cream pie',
#   'dutch apple pie',
#   "kit kat & reese's assorted miniatures",
#   'eggo homestyle waffles',
#   'extra long grain enriched rice',
#   'spaghetti',
#   'chunky roasted garlic pasta sauce',
#   '100% natural tomato sauce',
#   'cheese creations classic alfredo cheese sauce',
#   'natural goodness 33% less sodium chicken broth',
#   'chicken granulated bouillon',
#   'squeeze tomato ketchup',
#   'sweet & sour sauce',
#   'teriyaki chicken',
#   'orange chicken sauce',
#   'boneless pork loin chops',
#   'ground pork, extra lean, 4% fat',
#   'classic pork links',
#   'classic bacon',
#   'boneless skinless chicken breast',
#   'tilapia fillets',
#   'nova smoked atlantic salmon',
#   'organic fuji apple',
#   'golden delicious apple',
#   'seedless red grapes',
#   'blueberries',
#   'kiwi',
#   'mini watermelon',
#   'taylor organic baby herb salad',
#   'fresh spinach',
#   'whole white mushrooms',
#   'c&w frozen petite sweet corn',
#   'large wraps eggroll',
#   'chicken fried rice',
#   'rice a roni fried rice',
#   'teriyaki chicken flavor chow mein noodles',
#   'reduced fat 2% lactose-free milk'],
#  ['bag of organic bananas',
#   'clementines',
#   'teriyaki chicken',
#   'crunchy rice rollers'],
#  ['strawberries',
#   'teriyaki chicken',
#   'premium sliced bacon',
#   'honeycrisp apples',
#   'cheez-it baked snack crackers',
#   'cinnamon toast crunch',
#   'popcorn',
#   'organic medium salsa',
#   'organic low fat milk',
#   'romaine hearts',
#   'vegetable tray with low fat dressing'],
#  ['blueberries',
#   'raspberries',
#   'green seedless grapes',
#   'teriyaki chicken',
#   'orange chicken',
#   'grilled chicken taquitos',
#   'organic ketchup'],
#  ['diapers size 1',
#   'solid white albacore tuna',
#   'teriyaki chicken',
#   'ice cream variety pack'],
#  ['whole grain white corn salted tortilla chips',
#   'restaurant style medium salsa',
#   'large grade a eggs',
#   'purified water',
#   'hamburger buns',
#   'carrot chips',
#   'carrot cake slice',
#   'cheese fix flavored snack mix',
#   'asian salad kit',
#   'natural sharp cheddar sliced cheese',
#   'whole grain cheddar baked goldfish crackers',
#   'fun size candy bars',
#   'super soft flour tortillas fajita size 20 ct',
#   'frozen breaded bagged chicken nuggets',
#   'beef taquitos',
#   'teriyaki chicken',
#   'extra virgin olive oil',
#   'vegetable oil, pure & 100% natural'],
#  ['freshly made. filled with creamy ricotta, aged parmesan and romano cheeses three cheese tortellini',
#   'spinach & ricotta tortelloni',
#   'teriyaki chicken',
#   'truffle parmesan macaroni & cheese bowl',
#   'de mexico',
#   'coke classic',
#   'disinfecting wipes, lemon scent',
#   "kellogg's pop-tarts frosted strawberry pastries",
#   "slow kettle kickin' crab & sweet corn chowder soup",
#   'gingerman sweet and simple cookkies',
#   '2% reduced fat milk',
#   'pop-tarts wildlicious'],
#  ['clean care mega rolls toilet paper',
#   'fat free milk',
#   'lotion with aloe & e upright facial tissue',
#   'beef short ribs',
#   'chopped onions',
#   'teriyaki chicken',
#   'purified water',
#   'chewy granola bars variety pack',
#   'cranberry juice cocktail',
#   '100% pineapple juice',
#   'russet potatoes'],
#  ['unsweetened almondmilk',
#   'bag of organic bananas',
#   'organic lowfat 1% milk',
#   'ancient grain original granola',
#   'organic hass avocado',
#   'feta cheese crumbles',
#   'organic red onion',
#   'heart to heart honey toasted oat cereal',
#   'organic quick oats',
#   'organic red on the vine tomato',
#   'organic red bell pepper',
#   'orange bell pepper',
#   'organic ginger root',
#   'apples, kale & avocados organic baby food',
#   'organic chicken strips',
#   'all natural original guacamole mix',
#   'seedless red grapes',
#   'organic garnet sweet potato (yam)',
#   'spinach pizza',
#   'margherita pizza',
#   'teriyaki chicken',
#   'fresh cauliflower',
#   'rustic cut organic ruby red beets',
#   'organic chili spicy',
#   'organic extra large brown eggs',
#   'organic multigrain waffles',
#   'shredded mild cheddar cheese'],
#  ['steak strips',
#   '0% greek strained yogurt',
#   'hawaiian style teriyaki chicken bowl',
#   'low sodium original 100% vegetable juice',
#   'breaded chicken breast patties',
#   'teriyaki chicken',
#   'bag of organic bananas',
#   'blueberries',
#   'smokehouse almonds',
#   'stir fry vegetables'],
#  ['lemon dish liquid',
#   'microwaveable whole grain brown rice 2 ct',
#   'tomato ketchup',
#   'power & free multi-purpose cleaner',
#   'naturally hickory smoked thick cut bacon',
#   '2% reduced fat milk',
#   'red vine tomato',
#   'large grade aa eggs',
#   'chicken a la king',
#   'ultra premium bath tissue double rolls',
#   'maximum absorbency long length incontinence pads',
#   'brightly lint-free paper towel',
#   "organic d'anjou pears",
#   'salisbury steak',
#   'fettuccine alfredo with chicken & broccoli',
#   'beef & peppers with rice',
#   'chicken enchiladas',
#   'teriyaki chicken'],
#  ['teriyaki chicken',
#   'chicken wings',
#   "roarin' waters wild cherry water beverage",
#   '100% apple juice, original',
#   'ready rice roasted chicken flavored'],
#  ['bag of organic bananas',
#   'seedless red grapes',
#   'seasoning sauce',
#   'teriyaki chicken',
#   'fresh asparagus',
#   'pulp free orange juice',
#   'organic ketchup',
#   'organic extra virgin olive oil',
#   'leaf spinach'],
#  ['teriyaki chicken'],
#  ['teriyaki chicken', 'organic fudge bars'],
#  ['primo thin margherita pizza', 'teriyaki chicken'],
#  ['quinn butter and sea salt popcorn',
#   'simply smart gluten free breaded chicken breast tenders',
#   'teriyaki chicken',
#   'sesame street organic mini blueberry pancakes',
#   'vicks dayquil cold & flu multi-sympton relief',
#   'glacier freeze'],
#  ['smoked pulled pork', 'teriyaki chicken'],
#  ['teriyaki chicken'],
#  ['extra light olive oil',
#   'smoked pulled pork',
#   'teriyaki chicken',
#   'packaged grape tomatoes',
#   'sugar substitute'],
#  ['bite size tortilla chips',
#   'half baked® ice cream',
#   'cherry garcia ice cream',
#   'butternut squash and sage ravioli',
#   'teriyaki chicken',
#   'gluten free chicken tikka masala',
#   'gluten free uncured bacon mac and cheese',
#   'lean and fit fire grilled chicken poblano'],
#  ['original hawaiian sweet rolls',
#   'organic 2% chocolate milk',
#   'organic spaghetti',
#   'moisturizing lotion',
#   'pure olive oil',
#   'organic strawberries',
#   'fully husked & trimmed super sweet corn',
#   'hass avocados',
#   'honeydew melon',
#   'teriyaki chicken',
#   'lettuce',
#   'seedless cucumbers',
#   'organic creamy tomato basil soup',
#   'xl pick-a-size paper towel rolls',
#   'fresh mozzarella all-natural sliced cheese'],
#  ['natural sharp cheddar sliced cheese',
#   'original potato chips',
#   'oven roasted turkey breast',
#   'bread, country buttermilk',
#   'turkey bacon',
#   'cream cheese',
#   'chicken breast nuggets',
#   'cereal',
#   'double strong bath tissue  rolls',
#   'chocolate mint creme sandwich cookies',
#   'light tuna chunk in water',
#   'extra crunchy peanut butter',
#   'squeeze grape jelly',
#   'classic yellow mustard',
#   'greenlight strike on box matches',
#   'organic fuji apple',
#   'mint chocolate chip grand ice cream',
#   'uncrustables peanut butter & grape jelly sandwich',
#   'teriyaki chicken'],
#  ['light semisoft cheese',
#   'raspberries',
#   'teriyaki chicken',
#   'graham crackers',
#   'coconut cookie thins'],
#  ['fresh asparagus',
#   'teriyaki chicken',
#   'frozen organic blueberries',
#   'organic baby spinach',
#   'brussels sprouts'],
#  ['water mineral',
#   'teriyaki & pineapple chicken meatballs',
#   'teriyaki chicken'],
#  ['celery sticks',
#   'crunchy rice rollers',
#   'bag of organic bananas',
#   'reduced fat 2% milk',
#   'low fat fudge bars',
#   'teriyaki chicken',
#   'fuji apples'],
#  ['creamy peanut butter',
#   'teriyaki chicken',
#   'chicken tenderloins in a tangy sweet & sour sauce with rice sweet & sour chicken',
#   'chicken tikka masala',
#   'black pepper chicken',
#   'chicken fried rice',
#   'packaging tape high performance',
#   'with raspberry lemonade'],
#  ['teriyaki chicken',
#   'steak strips',
#   'philly cheese steak',
#   'cooked shrimp',
#   'artichoke and jalapeño dip & spread',
#   'chicken enchilada casserole',
#   'dried mangos',
#   'movie theater butter microwave popcorn'],
#  ['purified water',
#   'oats & chocolate chewy bars',
#   'belvita blueberry breakfast biscuit packs',
#   "kellogg's nutri-grain blueberry cereal",
#   "land o' lakes mini moo's half & half",
#   'teriyaki chicken',
#   'broccoli & carrots with brown & wild rice',
#   'orange bell pepper',
#   'yellow bell pepper',
#   'glacier freeze frost',
#   'crispix rice & corn cereal',
#   'original nooks & crannies english muffins',
#   'original strawberry banana yogurt',
#   'gripz chips deluxe/cheez-it/grahams variety pack snacks'],
#  ['organic spring mix',
#   'roasted pine nut hummus',
#   'spinach artichoke dip',
#   'reduced fat 2% milk',
#   'hass avocados',
#   'organic tortilla chips',
#   'pretzel slider buns',
#   'mango peach salsa',
#   'with crispy almonds cereal',
#   'cherrios honey nut',
#   'teriyaki chicken',
#   'pierogi potato & cheese',
#   'smoked pulled pork'],
#  ['organic yellow onions',
#   'rainbow bell peppers',
#   'tikka masala',
#   'fresh asparagus',
#   'teriyaki chicken'],
#  ['seafood cocktail sauce',
#   'bosc pear',
#   'pizzeria-style crust supreme speciale pizza',
#   '2% reduced fat milk',
#   'lemon-lime 12 pack soda',
#   'french vanilla creamer',
#   'shredded sharp cheddar cheese',
#   'low fat chocolate milk',
#   'apple juice',
#   'light mozarella string cheese',
#   'sweet rolls',
#   'italian dry salame',
#   'dinner plates',
#   'hazelnut spread with skim milk & cocoa',
#   'jasmine ready rice',
#   'smooth ranch dip',
#   'original body wash',
#   'one & done refreshing cucumber & green tea baby wipes',
#   'real aged cheddar macaroni & cheese',
#   'paper towels white w/ thirst pockets',
#   'crunchy breaded fish fillets',
#   'organic blackberries',
#   'apple apple applesauce on the go pouches',
#   'dry roasted lightly salted edamame',
#   'teriyaki chicken',
#   'fresh cut green beans',
#   'whole baby corn',
#   'american cheese slices 12 count',
#   'pear foam pump',
#   'spring water antibacterial liquid hand soap with moisturizer',
#   'corn & butter sauce steamers',
#   'lightly sauced roasted red potatoes',
#   'raisin bran cereal',
#   'endurance cool wave clear gel anti-perspirant & deodorant',
#   'teriyaki  beef jerky',
#   'eggo mini homestyle waffles',
#   'vanilla coke zero',
#   'california clementines',
#   'country rich syrup'],
#  ['organic vegetable broth',
#   'organic lemonade',
#   'beef franks',
#   'fresh scent laundry detergent',
#   'pretzel slider buns',
#   'pulp free orange juice',
#   'teriyaki chicken',
#   'chocolate chip cookies'],
#  ['oranges',
#   'premium grapefruit large',
#   'smoked whitefish salad',
#   'seltzer water',
#   'beefsteak tomatoes',
#   'taboule salad',
#   'roasted pine nut hummus',
#   'seedless cucumbers',
#   'honeydew melon',
#   'strawberries',
#   'fat free skim milk',
#   'teriyaki chicken'],
#  ['original strawberry low fat yogurt',
#   'crispy thin crust white pizza',
#   'chicken pad thai with rice noodles',
#   'buffalo style chicken strips',
#   'ranch dressing',
#   'french style green beans',
#   'steamers healthy vision vegetable blend',
#   'mediterranean blend steamers',
#   'teriyaki chicken',
#   'original baked whole grain wheat crackers',
#   'roasted garlic family size hummus'],
#  ['mild red enchilada sauce',
#   'organic mexican blend finely shredded cheese',
#   'traditional size corn tortillas, 6\\"',
#   'organic hass avocado',
#   'thick & chunky salsa',
#   'bag of organic bananas',
#   'super spinach! baby spinach, baby bok choy, sweet baby kale',
#   'calcium enriched 100% lactose free fat free milk',
#   'chicken breast tenders breaded',
#   'teriyaki chicken bowl',
#   'cherries & almonds in dark chocolate, 55% cocoa',
#   'organic sweet potato spirals',
#   'teriyaki chicken',
#   'apple honeycrisp organic',
#   'organic homestyle waffles',
#   'organic banana'],
#  ['smartwater',
#   'sweet kale salad mix',
#   'baby cucumbers',
#   'pain relief tablets',
#   'teriyaki chicken'],
#  ['organic milk reduced fat, 2% milkfat',
#   'eggo bites chocolatey chip pancakes',
#   'teriyaki chicken'],
#  ['special k chocolatey delight pastry crisps',
#   'special k cookies & crème pastry crisps',
#   'kettle cooked sea salt & cracked pepper potato chips',
#   'original chocolate chip cookies',
#   'milano milk chocolate cookies',
#   'fudge cremes sandwich cookies',
#   'milano melts cookies, dark classic crème',
#   'vanilla cookie',
#   'with seasoned roasted potatoes scrambled eggs & sausage',
#   'black pepper chicken',
#   'teriyaki chicken',
#   'seltzer water',
#   'cookie dipped drumsticks',
#   'toilet bowl cleaner with bleach rain clean',
#   'classic lavender & chamomile liquid hand soap',
#   'banana'],
#  ['butter with olive oil & sea salt',
#   'sweet mini sub rolls',
#   'original baked snack crackers',
#   'premium bun length beef franks',
#   'hot dog buns',
#   'caramel minis size chocolate cookie bar candy 11.5-oz. bag',
#   'butterfinger smooth & crunchy peanut butter cups',
#   'chicken breast nuggets',
#   'mac and cheese',
#   'provolone cheese slices',
#   'teriyaki chicken',
#   'pork potstickers'],
#  ['orange chicken',
#   'bag of large lemons',
#   'teriyaki chicken',
#   'cherrios honey nut',
#   'beef hot dogs',
#   'shredded mexican blend cheese',
#   'golden pineapple',
#   'organic strawberries',
#   'mini seedless watermelon pack',
#   'organic spring mix',
#   'flour tortillas',
#   'split top wheat bread'],
#  ['cereal',
#   'bag of large lemons',
#   'whole grain cheddar baked snack crackers',
#   'teriyaki chicken',
#   'bag of organic bananas',
#   'organic extra virgin olive oil',
#   'baked beans'],
#  ['grilled chicken strips',
#   'club delight sausage, egg, & cheese sandwiches',
#   'teriyaki chicken'],
#  ['organic tortilla chips',
#   'organic strawberries',
#   'angus cheeseburgers',
#   'frozen organic blueberries',
#   'parmesan crisps',
#   'teriyaki chicken',
#   'pure irish butter'],
#  ['plain non-fat greek yogurt',
#   'grape tomatoes',
#   'banana',
#   'quart storage bags',
#   'freezer gallon bags',
#   'teriyaki chicken'],
#  ['rainbow bell peppers',
#   'zero calorie cola',
#   'small curd lowfat 2% milkfat cottage cheese',
#   'teriyaki chicken',
#   'pineapple chunks',
#   'boneless & skinless chicken breasts',
#   'bag of jumbo yellow onions'],
#  ['organic low fat milk',
#   'farmhouse oatmeal hearty sliced bread',
#   'pure & natural sour cream',
#   'organic salted butter',
#   'organic black beans',
#   'fuji apples',
#   'shredded mexican blend cheese',
#   'teriyaki chicken',
#   'hass avocados'],
#  ['teriyaki chicken', 'baby cucumbers', 'mozzarella di bufala campana'],
#  ['organic honey sweet whole wheat bread',
#   'real aged cheddar macaroni & cheese',
#   'russet potato',
#   'arnica montana 200ck homeopathic pellets',
#   'green peas',
#   'tangerine 1,000 mg vitamin c dietary supplement',
#   'organic strawberries',
#   'organic zucchini spirals',
#   'chicken pad thai with rice noodles',
#   'organic reduced fat 2% milk',
#   'chicken biryani',
#   'chicken enchilada bowl',
#   'enchiladas al chipotle',
#   'teriyaki chicken',
#   'organic honey mustard dressing',
#   'organic olive oil  spray',
#   'organic appleapple',
#   'yokids squeeze organic blueberry blue yogurt',
#   '1% lowfat milk',
#   'bag of organic bananas'],
#  ['raspberries',
#   'breakfast essentials rich milk chocolate complete nutritional drink',
#   'peanut chocolate candy',
#   'pure irish butter',
#   'creamy peanut butter',
#   'teriyaki chicken',
#   'salt & pepper pistachios'],
#  ['organic animal crackers',
#   'apricots',
#   'beef franks',
#   'party pack hot dog buns',
#   'original hawaiian sweet rolls',
#   'ground saigon cinnamon',
#   'teriyaki chicken'],
#  ['blackberries', 'blueberries', 'organic tortilla chips', 'teriyaki chicken'],
#  ['organic low fat milk',
#   'tall kitchen bag with febreze odor shield',
#   'teriyaki chicken'],
#  ['organic sweet vanilla bean nutrition complete protein shake',
#   'organic nutritional shake strawberries & cream',
#   '100% recycled paper towels',
#   'cedarwood deodorant',
#   'pad thai',
#   'teriyaki chicken',
#   'asian noodle, stir fry',
#   'pita chips, simply naked'],
#  ['baby cucumbers', 'chocolate powder', 'teriyaki chicken'],
#  ['alaskan salmon burgers',
#   'organic strawberries',
#   'xl pick-a-size paper towel rolls',
#   'teriyaki chicken'],
#  ['bag of large lemons', 'liquid egg whites', 'teriyaki chicken'],
#  ['hard boiled eggs peeled & ready to eat',
#   'seedless cucumbers',
#   '90 calorie chocolate fudge brownies',
#   'teriyaki chicken',
#   'hass avocados',
#   'coconut water',
#   'blackberries',
#   'pulp free orange juice'],
#  ['100% tangerine juice',
#   'jumbo assortment cereal',
#   'teriyaki chicken',
#   'chicken enchilada casserole',
#   'strawberries',
#   'honeydew melon',
#   'golden pineapple',
#   'blackberries'],
#  ['cheez-it cheddar cracker',
#   'vanilla coke zero',
#   '2% reduced fat milk',
#   'french vanilla creamer',
#   'pizzeria-style crust supreme speciale pizza',
#   'low fat chocolate milk',
#   'apple juice',
#   'sweet rolls',
#   'italian dry salame',
#   'jasmine ready rice',
#   'one & done refreshing cucumber & green tea baby wipes',
#   'real aged cheddar macaroni & cheese',
#   'dinner plates',
#   'paper towels white w/ thirst pockets',
#   'original body wash',
#   'organic blackberries',
#   'teriyaki chicken',
#   'california clementines',
#   'apple apple applesauce on the go pouches',
#   'baked & popped variety snack packs',
#   'cage free brown eggs-large, grade a',
#   'whole baby corn',
#   'fresh cut green beans',
#   'lightly sauced roasted red potatoes',
#   'corn & butter sauce steamers',
#   'sweet sliced apples',
#   'grape jelly',
#   'smoked sausage',
#   'pure irish butter',
#   'dark chocolate covered peppermint patties party bag',
#   "steamfresh chef's favorites lightly sauced creamed spinach",
#   'hickory smoked turkey breast',
#   'baking soda & peroxide whitening with tartar protection fresh mint toothpaste twin',
#   'minions mild bubble fruit toothpaste',
#   'select natural applewood smoked turkey breast',
#   'mixed fruit snacks',
#   'no more tears baby shampoo'],
#  ['baked scalloped potatoes',
#   'teriyaki chicken',
#   'smoked pulled pork',
#   'smoked turkey bacon',
#   'strawberries',
#   'butternut squash'],
#  ['chicken tikka masala',
#   "classic pate mariner's catch cat food",
#   'blueberry bagels',
#   'soft cream cheese',
#   'sweet potato julienne fries',
#   'white cheddar popcorn',
#   'milano mint cookies',
#   'no beans chili',
#   'original cream cheesecake',
#   'swedish meatballs',
#   'fresh chicken drumsticks',
#   'clean comfort antiperspirant deodorant',
#   'chocolate chip cookie dough',
#   'vanilla ice cream',
#   'teriyaki chicken'],
#  ['teriyaki chicken', 'sweet whole gherkins'],
#  ['organic strawberries',
#   'raspberries',
#   'dry roasted macadamias with sea salt',
#   'packaged grape tomatoes',
#   'teriyaki chicken'],
#  ['hass avocados',
#   'ranchero queso fresco cheese',
#   'bag of organic bananas',
#   'corn tortillas',
#   'raspberries',
#   'strawberries',
#   'clementines',
#   'bag of large lemons',
#   'cinnamon toast crunch',
#   'pumpkin pie',
#   'crescent rolls',
#   'teriyaki chicken',
#   'pulp free orange juice'],
#  ['four fruits preserves',
#   'teriyaki chicken',
#   'mini seedless watermelon pack',
#   'rainbow bell peppers',
#   'organic crimini mushrooms'],
#  ['raspberries',
#   'broccoli florettes',
#   'organic chicken stock',
#   'strawberries',
#   'variety pack',
#   'moisturizing lotion',
#   'organic tomato sauce',
#   'teriyaki chicken'],
#  ['organic half & half',
#   'canola oil',
#   'roasted pine nut hummus',
#   'teriyaki chicken'],
#  ['ground ginger',
#   'ginger snaps',
#   'extra light olive oil',
#   'squeeze tomato ketchup',
#   'original barbecue sauce',
#   'spreadable butter with canola oil',
#   'diet coke caffeine free soda',
#   'lemonade drink mix',
#   'cheese creations classic alfredo cheese sauce',
#   'yellow onions',
#   'roma tomato',
#   'whole white mushrooms',
#   'flat parsley, bunch',
#   'broccoli crown',
#   'mixed bell peppers',
#   'taylor organic baby herb salad',
#   'garnet sweet potato (yam)',
#   'hass avocado bag',
#   'kiwi',
#   'honeydew melon',
#   'banana',
#   'bag of oranges',
#   'eggo buttermilk waffles',
#   'classic decaf medium decaffeinated ground coffee',
#   'mayonnaise with olive oil',
#   'classic bacon',
#   'classic pork links',
#   'natural hickory smoked canadian bacon center cut from pork loin',
#   'light tuna chunk in water',
#   'nova smoked atlantic salmon',
#   'boneless pork loin chops',
#   'hamburger buns',
#   'peach pie',
#   'creme pie, chocolate',
#   'pure vanilla extract',
#   'pineapple slices in heavy syrup',
#   'caramel syrup',
#   'genuine chocolate flavor syrup',
#   'cinnamon swirl raisin bread',
#   'split top white bread',
#   'french bread',
#   'roasted garlic & onion pasta sauce',
#   'spaghetti',
#   'penne pasta',
#   'rotini pasta',
#   'orzo pasta',
#   'chicken granulated bouillon',
#   'natural goodness 33% less sodium chicken broth',
#   'activia peach/strawberry lowfat yogurt',
#   'mandarin orange chicken',
#   'cinnamon swirl crumb cake & muffin mix',
#   'decadent classic yellow cake mix',
#   'super moist chocolate fudge cake mix',
#   'honey nut cheerios',
#   'shredded parmesan cheese',
#   'paper towels choose-a-sheet, mega rolls, one-ply',
#   'teriyaki chicken',
#   'teriyaki marinade & sauce',
#   'preservative free teriyaki with honey and pineapple marinade',
#   'sweet & sour sauce',
#   'tai pei      14oz.sweet & sour chkn',
#   'pita chips simply naked',
#   'hint of lime flavored tortilla chips',
#   'traditional snack mix',
#   'tiny twists pretzels',
#   'fudge stripes original cookies',
#   'original baked whole grain wheat crackers',
#   'original wheat thins',
#   'original fresh stack crackers',
#   'white cheddar popcorn',
#   'dry roasted lightly salted peanuts',
#   'honey roasted peanuts'],
#  ['plus lubricant eye drops',
#   'club delight sausage, egg, & cheese sandwiches',
#   'red seedless grapes',
#   'teriyaki chicken'],
#  ['organic medium salsa',
#   'organic strawberries',
#   'honeycrisp apples',
#   'popcorn',
#   'marinara sauce',
#   'lettuce',
#   'cinnamon toast crunch',
#   'teriyaki chicken',
#   "danimals drinkable yogurt smoothie strawberry explosion & strikin' strawberry kiwi",
#   'bartlett pears',
#   'organic chicken stock',
#   'organic beef base',
#   'thin crust pepperoni pizza'],
#  ['orange & lemon flavor variety pack sparkling fruit beverage',
#   'cup noodles chicken flavor',
#   'clementines',
#   'organic blueberries',
#   'baby cucumbers',
#   'chocolate chip cookies',
#   'vegetable chips',
#   'crunchy rice rollers',
#   'green seedless grapes',
#   'packaged grape tomatoes',
#   'chicken burrito bowl',
#   'pretzel slider buns',
#   'party pack hot dog buns',
#   'teriyaki chicken'],
#  ['heart healthy mix',
#   'cranberry juice cocktail',
#   'chunky new england clam chowder',
#   'mint ice cream sandwiches',
#   'sourdough deli bread',
#   'original baked  potato chips',
#   'double stuf oreo sandwich cookies',
#   'hickory ham & cheddar in a croissant crust',
#   'butternut squash and sage ravioli',
#   'egg, uncured bacon & cheese scramble cups',
#   'teriyaki chicken',
#   'whole milk',
#   'tortilla triangles restaurant style chips',
#   'frozen dairy dessert blasts girl scouts thin mints',
#   'slow churned no sugar added vanilla ice cream',
#   'extra whitening toothpaste',
#   'pro-health advanced extra deep clean anticavity fluoride mouthwash',
#   'chewy 25% low sugar chocolate chip granola',
#   'classic potato chips',
#   'chicken corn chowder soup',
#   'chunky grilled chicken & sausage gumbo soup'],
#  ['baby cucumbers',
#   'raspberries',
#   '100% apple juice',
#   'broccoli florettes',
#   'fuji apples',
#   'organic green beans',
#   'packaged grape tomatoes',
#   'sinfully sweet campari tomatoes',
#   'rainbow bell peppers',
#   'marinara sauce',
#   'smartwater',
#   'original almondmilk',
#   'brussels sprouts',
#   'green seedless grapes',
#   'solid white albacore tuna',
#   'xl pick-a-size paper towel rolls',
#   'teriyaki chicken',
#   'organic long grain brown rice',
#   'organic turkey breast',
#   'organic baby spinach'],
#  ['shredded mozzarella cheese',
#   'sparkling mineral water',
#   'worcestershire sauce',
#   'teriyaki chicken',
#   'trail mix'],
#  ['all natural white vinegar',
#   'organic lowafat 1% milk',
#   'natural artesian water',
#   'aged white cheddar popcorn',
#   'teriyaki chicken',
#   'grilled chicken taquitos',
#   'blueberry muffins'],
#  ['2% reduced fat milk',
#   'special k fruit & yogurt cereal',
#   'crispy rounds tortilla chips',
#   'organic avocado',
#   'chicken fried rice',
#   'teriyaki chicken',
#   'swedish meatballs',
#   'all natural virgin lemonade',
#   'creamy peanut butter',
#   'philadelphia cream cheese spread',
#   'black pepper chicken',
#   'favorites alfredo pasta with chicken & broccoli',
#   'glazed chicken',
#   'chunky classic salsa medium',
#   '4 cheese mexican shredded cheese'],
#  ['cherrios honey nut', 'teriyaki chicken', 'fabric softener sheets'],
#  ['stir fry vegetables',
#   'teriyaki chicken',
#   'thin crust pepperoni pizza',
#   'vanilla milk chocolate almond ice cream bars multi-pack'],
#  ['organic half & half',
#   'organic blackberries',
#   'water mineral',
#   'fresh asparagus',
#   'pumpkin pie',
#   'low sodium bacon',
#   'grape seed oil',
#   'cauliflower crumbles',
#   'teriyaki chicken'],
#  ['mango peach salsa',
#   'bag of organic bananas',
#   'teriyaki chicken',
#   'beef stroganoff',
#   'chicken pot pie',
#   'orange chicken',
#   'vanilla milk chocolate almond ice cream bars multi-pack',
#   '0% greek strained yogurt'],
#  ['bag of organic bananas',
#   'organic tortilla chips',
#   'teriyaki chicken',
#   'life cereal',
#   'moisturizing cream'],
#  ['hass avocados',
#   'peaches',
#   'lemonade drink mix',
#   'vanilla milk chocolate almond ice cream bars multi-pack',
#   'barbecue sauce',
#   'teriyaki chicken'],
#  ['packaged grape tomatoes',
#   'baby cucumbers',
#   'prosciutto di parma',
#   'soda',
#   'diet',
#   'sweet & salty nut granola bars peanut',
#   'peppermint patties',
#   'teriyaki chicken',
#   'chicken pot pie'],
#  ['chicken pot pie',
#   'reduced fat 2% milk',
#   'gourmet tomato medley',
#   '8\\" flour tortillas de harina',
#   'teriyaki chicken',
#   'grilled chicken taquitos',
#   'seedless red grapes'],
#  ['coke classic',
#   'pure leaf raspberry',
#   'french onion dip',
#   'blueberries',
#   'strawberries',
#   "bernie's farm animal cookies snack packs",
#   'medium scarlet raspberries',
#   'deli fresh smoked turkey breast',
#   'brown sugar cinnamon pre-sliced mini bagels',
#   'original thin bacon cheeseburger pizza',
#   '2% reduced fat milk',
#   'white meat chicken, shredded cabbage, julienne yellow carrots and spicy red coconut flavored curry thai-style chicken spring rolls',
#   '100% apple juice',
#   'organic pancake syrup',
#   "organic slammers superfood snack chill'n fruit, veggie & yogurt filled pouches",
#   'dm fusions peach mango',
#   'sparkling raspberry lime natural spring water',
#   'milk chocolate english toffee miniatures candy bars',
#   'mozzarella sticks',
#   'ultra  april fresh scent liquid fabric softener',
#   'blueberry mini bagels',
#   'original cream cheese',
#   'teriyaki chicken',
#   'mandarin orange & grapefruit hand wash 12 oz',
#   'raspberries',
#   'original petroleum jelly'],
#  ['hass avocados',
#   'dried mangoes',
#   'shredded mexican blend cheese',
#   'mozzarella di bufala campana',
#   'grilled chicken strips',
#   'teriyaki chicken'],
#  ['teriyaki chicken',
#   'cranberry walnut salad cafe bowl',
#   'bistro bowl chicken caesar salad'],
#  ['packaged grape tomatoes',
#   'seedless cucumbers',
#   'deep green blends kale',
#   'cherrios honey nut',
#   'hass avocados',
#   'organic blueberries clamshell',
#   'organic strawberries',
#   'apples',
#   'teriyaki chicken',
#   'shredded mexican blend cheese'],
#  ['reduced fat 2% milk',
#   'pure irish butter',
#   'seedless red grapes',
#   'hass avocados',
#   'teriyaki chicken',
#   'packaged grape tomatoes'],
#  ['2% reduced fat milk',
#   'microwaveable 100% beef cheeseburgers',
#   'bacon cheeseburger',
#   'beef & bean green chili burritos',
#   'danimals strawberry explosion flavored smoothie',
#   'eggo buttermilk pancakes',
#   'teriyaki chicken',
#   'combination party pizza',
#   'classic italian style meatballs',
#   'mozzarella finely shredded shredded cheese',
#   'spaghetti pasta',
#   'fudge brownie grand ice cream'],
#  ['100% carrot juice',
#   'teriyaki chicken',
#   'seasoning, coriander & annatto, jumbo pak'],
#  ['zero calorie cola', 'teriyaki chicken'],
#  ['soda', 'teriyaki chicken'],
#  ['cherrios honey nut',
#   'teriyaki chicken',
#   'creamy peanut butter',
#   'macaroni & cheese'],
#  ['2% reduced fat milk',
#   'jumbo wieners',
#   'raspberry blackberry sparkling water',
#   'peanut butter sandwich cookies',
#   'chicken salad',
#   'ham and cheese scramble tasty american favorites',
#   'with seasoned roasted potatoes scrambled eggs & sausage',
#   'shredded steak & cheese burrito',
#   'teriyaki chicken'],
#  ['baby cucumbers', 'teriyaki chicken'],
#  ['beefsteak tomatoes',
#   'organic chicken stock',
#   'plain water seltzer',
#   'leaf spinach',
#   'teriyaki chicken'],
#  ['clean care big roll toilet paper',
#   'gluten free blueberry waffles',
#   'indian aloo mattar wrap',
#   'teriyaki chicken',
#   'lemon mint foaming hand wash',
#   'extra virgin olive oil',
#   'triple-acting laundry stain remover',
#   'super soft flour tortillas',
#   'gluten free white sandwich bread',
#   'classic hummus family size',
#   'lemon mint dish soap',
#   'made with organic beans & rice burrito non-dairy',
#   'white giant paper towel rolls',
#   'non-stick parchment paper'],
#  ['super soft taco flour tortillas',
#   'traditional refried beans',
#   'mild chunky salsa',
#   'organic yellow squash',
#   'avocado',
#   'frosted toaster pastries, cherry pomegran',
#   'stage 2 blueberry, pear, and purple carrot baby food',
#   'original thin supreme pizza',
#   'dark chocolate with 88% cocoa',
#   'traditional favorites tomato & basil pasta sauce',
#   '100% whole wheat bread',
#   'natural pure sparkling water',
#   'vitamin d organic whole milk',
#   'organic strawberries',
#   'red bell pepper',
#   'uncured hickory smoked sunday bacon',
#   'organic bunny-luv carrots',
#   'celery',
#   "farmer's garden bread & butter",
#   'organic blue corn tortilla chips',
#   'caffeine free peppermint herbal tea',
#   'cozy chamomile herbal tea',
#   'organic blueberries',
#   'cinnamon multigrain cereal',
#   'orange calcium & vitamin d pulp free',
#   'teriyaki chicken',
#   'lorna doone shortbread cookies'],
#  ['premium solid white albacore tuna in water', 'teriyaki chicken'],
#  ['thin crust pepperoni pizza',
#   'teriyaki chicken',
#   'tikka masala',
#   'grilled chicken strips',
#   'gourmet tomato medley',
#   'tortilla strips',
#   'blackberries'],
#  ['high-traffic foam large area carpet cleaner',
#   'disinfecting wipes fresh scent',
#   'teriyaki chicken',
#   'orange chicken'],
#  ['teriyaki chicken',
#   'unsweetened vanilla almond breeze',
#   'fuji apples',
#   'kiwi',
#   'organic egg whites',
#   'coconut water',
#   'hass avocado variety'],
#  ['whole kernel corn no salt added',
#   '50% less sodium garbanzo beans',
#   'organic blueberries',
#   'chicken breast tenders',
#   'panko italian style crispy bread crumbs',
#   'shredded low-moisture part-skim mozzarella cheese',
#   'penne pasta',
#   'large lemon',
#   'kosher salt',
#   'banana',
#   'organic shiitake mushrooms',
#   'marsala cooking wine',
#   'lightly dried parsley',
#   'shallot',
#   'teriyaki chicken',
#   'organic hass avocado',
#   'organic cauliflower',
#   'red onion'],
#  ['half and half cream',
#   'medium roast ground coffee',
#   'farmhouse oatmeal hearty sliced bread',
#   'table water crackers',
#   'strawberries',
#   'original almondmilk',
#   'teriyaki chicken',
#   'organic black beans',
#   'organic 2% milk',
#   'brussels sprouts'],
#  ['smoked pulled pork',
#   'original rice krispies treats',
#   'teriyaki chicken',
#   'green tea',
#   'plain bagels',
#   'primo thin margherita pizza',
#   '2% lactose free milk'],
#  ['ibuprofen',
#   '100% carrot juice',
#   'teriyaki chicken',
#   'best cinnamon bread',
#   'fabric softener dryer sheet outdoor fresh 160ct fabric enhancers',
#   'tall kitchen bag with febreze odor shield'],
#  ['teriyaki chicken',
#   'pure irish butter',
#   'organic frozen peas',
#   'chicken apple sausage',
#   'blueberries'],
#  ['apples',
#   'organic ketchup',
#   'sparkling mineral water',
#   'mozzarella ciliegine',
#   'pure cane granulated white sugar',
#   'teriyaki chicken',
#   'cinnamon brown sugar breakfast biscuits',
#   'trail mix',
#   'green seedless grapes'],
#  ['bag of organic bananas',
#   'breakfast patties',
#   'teriyaki chicken',
#   'strawberries',
#   'vegetable juice',
#   'clementines',
#   'chocolate wafers candy bar'],
#  ['bag of organic bananas',
#   "crunchy oats 'n honey granola bars",
#   'organic tortilla chips',
#   'belgian waffles',
#   'coconut water',
#   'teriyaki chicken',
#   'fresh asparagus'],
#  ['2% milk',
#   'ultra thin pastrami',
#   'super soft taco flour tortillas',
#   'peanut butter & grape jelly sandwiches',
#   'whole kernel sweet corn',
#   'beef bologna',
#   'teriyaki chicken',
#   'medium cheddar cheese slices',
#   'colby and monterey jack cheeses finely shredded',
#   'deli select ultra thin honey ham',
#   'swirl thick slice brown sugar cinnamon bread',
#   'toll house butterscotch morsels',
#   'classic potato chips',
#   'classic roasted chicken oven sauce',
#   'loaded potato skins stuffed with cheddar cheese & bacon',
#   'automatic dish washing detergent lemon scent',
#   '8 skinless beef franks',
#   'pop-tarts frosted brown sugar cinnamon pastries'],
#  ['organic tortilla chips',
#   'raspberries',
#   'tri fun pack fruit loops, cocoa krispies; apple jacks',
#   'teriyaki chicken',
#   'cup noodles chicken flavor',
#   'ground saigon cinnamon',
#   'crushed red pepper',
#   'himalayan pink salt',
#   '50% less sodium chicken broth',
#   'crunchy rice rollers'],
#  ['small hass avocado',
#   'seedless red grapes',
#   'fat free milk',
#   'fresh ca grown eggs',
#   'shredded mild cheddar cheese',
#   'yellow corn taco shells',
#   'stick east coast vegetable oil spread',
#   'sugar free vanilla syrup',
#   'teriyaki chicken'],
#  ['teriyaki chicken',
#   'organic apple slices',
#   'strawberries',
#   'organic medium salsa',
#   'popcorn',
#   'cinnamon toast crunch',
#   'pears',
#   'peaches'],
#  ['chocolate milk cartons 2% reduced fat',
#   'organic broccoli florets',
#   "fusion proglide power men's razor blade refills",
#   'chicken apple sausage',
#   'bag of organic bananas',
#   'organic spring mix',
#   'organic fuji apples',
#   'packaged grape tomatoes',
#   'popcorn chicken',
#   'teriyaki chicken',
#   'french green beans'],
#  ['brioche hamburger buns',
#   'club delight sausage, egg, & cheese sandwiches',
#   'teriyaki chicken'],
#  ['organic simply naked pita chips',
#   'frosted flakes',
#   'original hawaiian sweet rolls',
#   'teriyaki chicken',
#   'chocolate chip cookies',
#   'strawberries'],
#  ['san francisco potato salad',
#   'coppertop aaa alkaline batteries',
#   'coppertop aa alkaline batteries',
#   'energy drink',
#   'teriyaki chicken',
#   'baby cucumbers',
#   'chunky peanut butter',
#   'hass avocados',
#   'golden pineapple'],
#  ['diet',
#   'celery sticks',
#   'sweetener',
#   'reduced fat 2% lactose-free milk',
#   'organic baby carrots',
#   'plain bagels',
#   'angus cheeseburgers',
#   'teriyaki chicken'],
#  ['bag of organic bananas',
#   'teriyaki chicken',
#   'heavy whipping cream',
#   'bunny-luv organic carrots',
#   'organic whole milk',
#   'organic sour cream',
#   'total 0% greek yogurt',
#   'romaine hearts',
#   'brussels sprouts'],
#  ['teriyaki chicken', 'green seedless grapes', 'blackberries'],
#  ['organic 2% milk', 'cherrios honey nut', 'teriyaki chicken', 'clementines'],
#  ['green tea',
#   'smartwater',
#   'teriyaki chicken',
#   'multi grain cheerios',
#   'liquid egg whites'],
#  ['spring water', 'soda', 'bag of organic bananas', 'teriyaki chicken'],
#  ['old world style organic traditional pasta sauce',
#   'ef california white basmati eco-farmed 2 lb rice',
#   'baby healing ointment',
#   'natural free & clear dish liquid',
#   'no msg cheddar wurst smoked sausage with wisconsin cheese',
#   'the original worcestershire sauce',
#   'grill mates worcestershire pub burger seasoning',
#   'hoisin sauce',
#   'original chicken patties',
#   'pad thai',
#   'teriyaki chicken',
#   'meatloaf in gravy',
#   'cauliflower florets',
#   'sweet red grape tomatoes',
#   'carrot chips',
#   'fresh cut brussels sprouts',
#   'california clementines',
#   'raspberries'],
#  ['cinnamon toast crunch', 'hot link sausage', 'teriyaki chicken'],
#  ['soda', 'teriyaki chicken'],
#  ['reduced fat 2% lactose-free milk',
#   'teriyaki chicken',
#   'frozen whole strawberries',
#   'organic crimini mushrooms'],
#  ['vanilla milk chocolate almond ice cream bars multi-pack',
#   'organic half & half',
#   'organic baby spinach',
#   'organic crimini mushrooms',
#   'shredded parmigiano reggiano',
#   'teriyaki & pineapple chicken meatballs',
#   'zebra popcorn',
#   'teriyaki chicken',
#   'red seedless grapes',
#   'seedless cucumbers'],
#  ['salame, italian dry',
#   'teriyaki chicken',
#   'ham & american funpack lunchable',
#   'organic milk reduced fat, 2% milkfat',
#   'organic bunny fruit snacks berry patch',
#   'raspberry lime essence sparkling mountain spring water'],
#  ['organic simply naked pita chips', 'teriyaki chicken'],
#  ['teriyaki chicken', 'broccoli florettes'],
#  ['soda',
#   'organic blackberries',
#   'bag of organic bananas',
#   'teriyaki chicken',
#   'italian dressing'],
#  ['raw shrimp',
#   'boneless skinless chicken breasts',
#   'honeydew melon',
#   'oranges',
#   'pears',
#   'green seedless grapes',
#   'hass avocados',
#   'golden pineapple',
#   'clementines',
#   'smoked pulled pork',
#   'teriyaki chicken'],
#  ['classic yellow mustard',
#   'tomato ketchup',
#   'english muffins',
#   'apple juice',
#   'diet coke caffeine free soda',
#   'cinnamon swirl raisin bread',
#   'activia peach/strawberry lowfat yogurt',
#   'split top white bread',
#   'whole white mushrooms',
#   'broccoli crown',
#   'original cream cheese',
#   'cranberry juice drink',
#   'fresh spinach',
#   'french bread',
#   'garlic bread',
#   'mild sliced cheddar cheese',
#   'cheese creations classic alfredo cheese sauce',
#   'jumbo franks',
#   'classic dinner rolls',
#   'hamburger buns',
#   'organic fuji apple',
#   'garnet sweet potato (yam)',
#   'eggo homestyle waffles',
#   'boneless pork loin chops',
#   'classic pork links',
#   'peach pie',
#   'mixed vegetables',
#   'flat parsley, bunch',
#   'reduced fat milk 100% lactose free',
#   'banana',
#   'mini watermelon',
#   'roma tomato',
#   'toaster size premium plain bagels',
#   'ultimate petite mixed vegetables',
#   'bag of oranges',
#   'white chip macadamia nut cookie dough',
#   'yellow onions',
#   'mixed bell peppers',
#   'shredded hash browns',
#   'cheese delicato ravioli',
#   'oral electrolyte solution mixed fruit',
#   'unflavored oral electrolyte solution',
#   'fresh cauliflower',
#   'organic bunny-luv fresh carrots',
#   'long grain & wild rice original rice mix',
#   'rice a roni fried rice',
#   'vodka pasta sauce',
#   'diced pears in light syrup fruit cups',
#   'sliced cooked ham',
#   'sweet & sour sauce',
#   'cantaloupe',
#   'green peas',
#   'artisan sausage pineapple uncured bacon hardwood smoked with vermont maple syrup',
#   'smoked sausage',
#   'cut baby corn',
#   'french style fresh cut green beans',
#   'bartlett pears',
#   'teriyaki chicken',
#   'whole kernel golden sweet corn',
#   'eggo buttermilk waffles',
#   'maraschino cherries',
#   'organic blackberries',
#   'seedless red grapes',
#   'chocolate ice cream',
#   'original whipped topping',
#   'whipped cream cheese frosting'],
#  ['classic roast',
#   'green seedless grapes',
#   'strawberries',
#   'baked scalloped potatoes',
#   'broccoli florettes',
#   'fresh asparagus',
#   'grilled chicken strips',
#   'vegetable oil',
#   'teriyaki chicken',
#   'reduced fat 2% milk',
#   'crescent rolls',
#   'buttermilk biscuit'],
#  ['heavy duty aluminum foil',
#   'vanilla ice cream',
#   'heavy whipping cream',
#   'brioche hamburger buns',
#   'thin crust pepperoni pizza',
#   'chocolate sandwich cookies',
#   'crescent roll cans',
#   'pure & natural sour cream',
#   'chunky guacamole',
#   'teriyaki chicken'],
#  ['bag of organic bananas',
#   'red plastic cups',
#   'bag of jumbo yellow onions',
#   'teriyaki chicken'],
#  ['teriyaki chicken'],
#  ['angus cheeseburgers', 'teriyaki chicken', 'pineapple chunks'],
#  ['club delight sausage, egg, & cheese sandwiches',
#   'chicken pot pie',
#   'teriyaki chicken'],
#  ['chocolate chip cookies',
#   'organic tortilla chips',
#   'classic roast',
#   'shredded mexican blend cheese',
#   'teriyaki chicken',
#   'indian paneer tikka',
#   'organic salted butter',
#   'original beef jerky'],
#  ['fire grilled steak bowl',
#   'smart & crunchy fish fillet',
#   'greek yogurt caesar kit',
#   'tomato & basil tomato sauce',
#   'extralean ground turkey breast',
#   'berry veggie juice smoothie',
#   'non fat black cherry on the bottom greek yogurt',
#   'peach on the bottom nonfat greek yogurt',
#   'flip pumpkin harvest crisp lowfat greek yogurt',
#   'curate cherry lime sparkling water',
#   'pineapple strawberry sparkling water',
#   'star wars italian sweet creme creamer',
#   'balanced breaks white cheddar with sea salted roasted almonds and dried cranberries',
#   'balanced breaks white cheddar with cashews & cranberries cheese snacks',
#   'fridge pack cola',
#   'zero mixed berry',
#   'salmon and tuna formula dry cat food',
#   'evercurl hydracharge conditioner',
#   'evercurl sulfate-free curl care system',
#   'wheat thins popped sour cream and onion',
#   'kitchen citrus bliss foaming hand soap',
#   'chicken enchilada bowl',
#   'organic green beans',
#   'foaming scrub pink grapefruit oil-free acne wash',
#   'mandarin oranges',
#   'instant pro banana nut oatmeal',
#   'braided twist honey wheat',
#   'teriyaki chicken',
#   'butternut squash and sage ravioli',
#   'goat cheese and portobello ravioli bowl',
#   'simply steamers meatball marinara',
#   'whips creamy whipped peanut butter',
#   'peanut butter & chocolate muddy buddies chex mix',
#   'apple, juicy red, family pack',
#   'complete lemon'],
#  ['baby cucumbers',
#   'sweet kale salad mix',
#   'sinfully sweet campari tomatoes',
#   'teriyaki chicken',
#   'smartwater'],
#  ['grape-nuts cereal',
#   'lavender dish soap',
# ...
#   'veggie cheese & pretzel snack pac prepacked',
#   'pink lady apples',
#   'red seedless grapes',
#   'sweet kale salad mix',
#   'teriyaki chicken',
#   'stir fry vegetables',
#   'multigrain bread',
#   'smoked pulled pork'],
#  ['teriyaki chicken'],
#  ['fat free milk',
#   'split top wheat bread',
#   'organic strawberry spread',
#   'organic diced tomatoes',
#   'teriyaki chicken',
#   'organic strawberries',
#   'beef hot dogs',
#   'traditional refried beans',
#   '0% greek strained yogurt'],
#  ['strawberries',
#   'original thin pepperoni pizza',
#   'lemonade with mango',
#   'whole vitamin d milk',
#   "kellogg's nutri-grain apple cinnamon cereal",
#   'organic blueberries',
#   'classic potato chips',
#   'sweet peas',
#   'mini cheeseburgers',
#   'eggo blueberry waffles',
#   'smartblend small bites beef & rice formula adult dog food',
#   'blueberry mini bagels',
#   'sweet rolls',
#   'white cheddar baked snack crackers',
#   'teriyaki chicken',
#   'coke classic',
#   'lemon-lime fridge pack soda'],
#  ['teriyaki chicken',
#   'tikka masala',
#   'club delight sausage, egg, & cheese sandwiches',
#   'hazelnut spread with cocoa'],
#  ['sweet kale salad mix',
#   'grilled chicken taquitos',
#   'hass avocados',
#   'roasted pine nut hummus',
#   'semi-sweet chocolate morsels',
#   'chocolate chip cookies',
#   'teriyaki chicken',
#   'organic tortilla chips',
#   'sea salt brown rice crackers',
#   'organic spring mix',
#   'classic baby creamers potatoes',
#   'solid white longline albacore tuna in water'],
#  ['organic shredded unsweetened coconut',
#   'honeycrisp apples',
#   'unsweetened coconut milk beverage',
#   'organic spicy chili',
#   'chipotle chicken mac & cheese',
#   'lean & fit coconut lemongrass chicken',
#   'chicken enchilada bowl',
#   'butternut squash and sage ravioli',
#   'teriyaki chicken',
#   'shredded chicken street taco + ancho aioli',
#   'spicy uncured bacon & egg roasted potato jalapeno & cheddar burrito',
#   'uncured ham-egg & cheddar multi-grain flatbread breakfast sandwich',
#   'dairy free coconut milk beverage',
#   'mint chip coconut milk ice cream'],
#  ['orange juice with calcium',
#   'mac & cheese, with roasted poblanos and chicken',
#   'prosciutto di parma',
#   'teriyaki chicken',
#   'dairy free unsweetened coconut milk',
#   'life cereal'],
#  ['teriyaki chicken',
#   'original rice krispies treats',
#   'cheez-it baked snack crackers'],
#  ['100% juice, variety pack',
#   'dried mangos',
#   'organic strawberries',
#   'oranges',
#   'teriyaki chicken',
#   'beef franks',
#   'organic animal crackers',
#   'organic unbleached all purpose flour',
#   'pure vanilla extract'],
#  ['house blend instant coffee',
#   'small curd lowfat 2% milkfat cottage cheese',
#   'teriyaki chicken',
#   'drinking water'],
#  ['organic chunky vegetable soup',
#   'mint chip coconut milk ice cream',
#   'organic roasted red pepper hummus',
#   'supreme pizza',
#   'gluten free garden vegetable lasagna',
#   'gluten free chicken tikka masala',
#   'teriyaki chicken',
#   'breaded popcorn turkey dogs'],
#  ['teriyaki chicken',
#   'santitas tortilla chips 14.5 oz',
#   'with raspberry lemonade',
#   'favorites alfredo pasta with chicken & broccoli',
#   'mushroom mezzluna ravioli',
#   'craveables chicken club panini',
#   'chicken & vegetable potstickers',
#   'black pepper chicken',
#   'rigatoni with chicken & pesto',
#   'dark & mint filled chocolate squares'],
#  ['teriyaki chicken',
#   'organic strawberries',
#   'smoked pulled pork',
#   'uncrustables peanut butter & grape jelly sandwich',
#   'sinfully sweet campari tomatoes',
#   'variety pack',
#   'chicken pot pie',
#   'boneless skinless chicken thighs',
#   'black seedless grapes'],
#  ['drumstick vanilla caramel frozen dairy dessert cones',
#   'buttermilk pancakes',
#   'cinnamon french toaster sticks',
#   'teriyaki chicken',
#   'mexican style fiesta',
#   'wonton strips',
#   'deep dish sausage & gravy pot pie'],
#  ['packaged grape tomatoes',
#   'hass avocados',
#   'blueberries',
#   'organic strawberries',
#   'pure irish butter',
#   'dry roasted almonds',
#   'green seedless grapes',
#   'veggie cheese & pretzel snack pac prepacked',
#   'baked scalloped potatoes',
#   'teriyaki chicken'],
#  ['romaine hearts',
#   'hass avocados',
#   'packaged grape tomatoes',
#   'organic tortilla chips',
#   'red bell peppers',
#   'pure & natural sour cream',
#   'raw shrimp',
#   'shredded parmigiano reggiano',
#   'reduced fat 2% milk',
#   'shredded mild cheddar cheese',
#   'mixed fruit fruit snacks',
#   'organic medium salsa',
#   'extra virgin olive oil',
#   'teriyaki chicken'],
#  ['fresh goat cheese',
#   'mango peach salsa',
#   'cinnamon toast crunch',
#   'cherrios honey nut',
#   "crunchy oats 'n honey granola bars",
#   'nutri grain bars multi pack',
#   'seedless red grapes',
#   'alaskan salmon burgers',
#   'teriyaki chicken',
#   'unsweetened vanilla almond breeze'],
#  ['red seedless grapes',
#   'hass avocado variety',
#   'natural spring water',
#   'teriyaki chicken',
#   'bag of organic bananas',
#   'pure clover honey',
#   'chunk light tuna',
#   'strawberries'],
#  ['teriyaki chicken'],
#  ['teriyaki chicken',
#   'original beef jerky',
#   'shredded mexican blend cheese',
#   'organic lemonade',
#   'chocolate chip cookies',
#   'indian paneer tikka'],
#  ['soda',
#   'chocolate chip cookies',
#   'zero calorie cola',
#   'bag of organic bananas',
#   'teriyaki chicken',
#   'original beef jerky',
#   'tall kitchen bag with febreze odor shield',
#   'organic tortilla chips'],
#  ["crunchy oats 'n honey granola bars",
#   'organic animal crackers',
#   'original dish liquid',
#   'baby cucumbers',
#   'heavy duty scrub sponge',
#   'sinfully sweet campari tomatoes',
#   'red plastic cups',
#   'organic tortilla chips',
#   'organic variety pack',
#   'orange chicken',
#   'pulp free orange juice',
#   'club delight sausage, egg, & cheese sandwiches',
#   'artichoke and jalapeño dip & spread',
#   'teriyaki chicken',
#   'mozzarella sticks'],
#  ['teriyaki & pineapple chicken meatballs',
#   'aged balsamic vinegar',
#   'teriyaki chicken'],
#  ['sugarfree',
#   '2% reduced fat milk',
#   'grape nutrient enhanced water beverage mix',
#   'mini ravioli',
#   'orange calcium & vitamin d pulp free',
#   'kiwi strawberry nutrient enhanced water beverage mix',
#   'assorted bites',
#   'organic cane sugar',
#   'original medium picante sauce',
#   'teriyaki chicken'],
#  ['natural spring water',
#   'romaine hearts',
#   'strawberries',
#   'sweet kale salad mix',
#   'teriyaki chicken',
#   'smoked gouda',
#   'gourmet tomato medley',
#   'fuji apples',
#   'teriyaki & pineapple chicken meatballs',
#   'organic cooked beets',
#   'sinfully sweet campari tomatoes',
#   'fresh asparagus',
#   'baby cucumbers'],
#  ['100% apple juice',
#   'teriyaki chicken',
#   'organic salted butter',
#   'cranberry juice cocktail',
#   'organic crimini mushrooms',
#   'golden pineapple',
#   'organic spring mix',
#   'fresh scent laundry detergent'],
#  ['organic spring mix',
#   'orange chicken',
#   'organic low fat milk',
#   'teriyaki chicken'],
#  ['pure irish butter',
#   'april fresh liquid fabric softener',
#   'sweet kale salad mix',
#   'organic strawberries',
#   'tall kitchen bag with febreze odor shield',
#   'strawberries',
#   'teriyaki chicken'],
#  ['soda',
#   'organic creamy tomato basil soup',
#   'small curd lowfat 2% milkfat cottage cheese',
#   'nacho cheese flavored tortilla chips',
#   'variety pack',
#   'teriyaki chicken',
#   'calrose rice'],
#  ['hass avocados',
#   'variety pack',
#   'tall kitchen bag with febreze odor shield',
#   'raspberries',
#   'green seedless grapes',
#   'sweet kale salad mix',
#   'braeburn apples',
#   'bag of organic bananas',
#   'teriyaki chicken',
#   'pineapple spears',
#   'strawberries',
#   'seedless cucumbers',
#   'celery hearts',
#   'leaf spinach',
#   'creamy peanut butter',
#   'hazelnut spread with cocoa'],
#  ['organic tortilla chips',
#   'teriyaki chicken',
#   'baked scalloped potatoes',
#   'chicken burrito bowl',
#   'soda'],
#  ['organic chicken stock',
#   'organic 2% chocolate milk',
#   'chocolate powder',
#   'teriyaki chicken'],
#  ['classic meal for 2 chicken florentine & farfalle',
#   'pesto tortellini  bowls',
#   'finely shredded parmesan cheese',
#   'spinach',
#   'organic blueberries',
#   'chicken & apple smoked chicken sausage',
#   'teriyaki chicken',
#   'italian sausage & rigatoni classic meal for 2',
#   'tomato basil garlic italian sauce',
#   'fresh mushroom  pasta sauce'],
#  ['teriyaki chicken'],
#  ['pure almond unsweetened original almond milk',
#   'macaroni and cheese',
#   'organic good seed bread',
#   'deli fresh smoked turkey breast',
#   'cucumber kirby',
#   'organic avocado',
#   'low moisture part skim mozzarella string cheese',
#   'cage free grade aa large white eggs',
#   'bun length beef franks',
#   'banana',
#   'spaghetti with meat sauce',
#   'teriyaki chicken',
#   'kids soft and chewy candy',
#   'fave reds fruit',
#   'orange with mango juice'],
#  ['organic fuji apples',
#   'organic strawberries',
#   'organic blueberries',
#   'golden pineapple',
#   'teriyaki chicken',
#   'mango peach salsa'],
#  ['pure clover honey',
#   'panko breaded chicken breast tenderloins',
#   'teriyaki chicken',
#   'organic acai juice',
#   'baked scalloped potatoes',
#   'non-scratch scrub sponges'],
#  ['organic chicken meatballs',
#   'teriyaki & pineapple chicken meatballs',
#   'tzatziki sauce',
#   'baked scalloped potatoes',
#   'teriyaki chicken',
#   'cauliflower crumbles',
#   'organic frozen peas',
#   'celery sticks'],
#  ['presliced everything bagels',
#   'freshly made pasta, rich meat sauce and real mozzarella cheese lasagna with meat & sauce',
#   'freshly made. filled with creamy ricotta, aged parmesan and romano cheeses three cheese tortellini',
#   'grab and go! stack potato crisps sour cream & onion flavored',
#   'gluten free smoked gouda mac and cheese',
#   'teriyaki stir fry kit',
#   "slow kettle kickin' crab & sweet corn chowder soup",
#   'slow kettle southwest-style chicken chili with beans soup',
#   'classic potato chips',
#   'disinfecting wipes, lemon scent',
#   'truffle parmesan macaroni & cheese bowl',
#   'teriyaki chicken',
#   'slow kettle thai chicken with rice',
#   'raisin bran crunch cereal',
#   '2% reduced fat milk',
#   'cherry coke',
#   'classic coke',
#   'pods laundry detergent, original designed for regular and he washers laundry'],
#  ['green seedless grapes',
#   'brussels sprouts',
#   'unsweetened vanilla almond breeze',
#   'teriyaki chicken'],
#  ['100% carrot juice',
#   'teriyaki chicken',
#   'chocolate chip cookies',
#   'premium solid white albacore tuna in water'],
#  ['fully husked & trimmed super sweet corn',
#   'tall kitchen bag with febreze odor shield',
#   'cherrios honey nut',
#   'organic extra virgin olive oil',
#   "crunchy oats 'n honey granola bars",
#   'baked beans',
#   'steak strips',
#   'teriyaki chicken'],
#  ['total 0% raspberry yogurt',
#   'fat free strawberry yogurt',
#   'cherry pomegranate greek yogurt',
#   'vanilla skyr nonfat yogurt',
#   'vanilla 0% milkfat yogurt',
#   'strained non fat orange & ginger yogurt',
#   'organic fat free milk',
#   'green tea with ginseng and honey',
#   'organic american cheese singles',
#   'light semisoft cheese',
#   'organic shredded mozzarella',
#   "elmo mac 'n cheese with carrots & broccoli",
#   'half baked frozen yogurt',
#   'roasted brussels sprouts',
#   'panko bread crumbs',
#   'all natural berry blast 100% juice smoothie',
#   'orange mango juice',
#   'protein zone protein juice smoothie',
#   'protein zone double berry juice smoothie',
#   'green machine juice smoothie',
#   'baby bee dusting powder',
#   'banana',
#   'teriyaki chicken',
#   'chicken noodle soup',
#   'strawberries',
#   'grape white/green seedless',
#   'thai coconut soup'],
#  ['cran-grape juice',
#   'oatnut bread',
#   'mashed potatoes',
#   'bag of organic bananas',
#   'vanilla bean ice cream',
#   "potatoes o'brien with onions and peppers",
#   'organic microwaveable pouches jasmine rice thai',
#   'classic macaroni & beef in tomato sauce',
#   'whole grain organic blueberry waffles',
#   'outshine fruit bars',
#   'pop-tarts frosted brown sugar cinnamon pastries',
#   'smoked chicken & apple mini sausages',
#   'teriyaki chicken',
#   'microwaveable 100% beef cheeseburgers',
#   'sliced sweet sandwich rolls',
#   'tomatoes',
#   'sugar free raspberry low calorie gelatin snacks',
#   'sugar free vanilla pudding',
#   'jelly, blackberry',
#   'vanilla cupcakes',
#   'organic living butter lettuce',
#   'natural deli style sliced swiss cheese',
#   'organic vanilla bean ice cream'],
#  ['popcorn', 'original rice krispies treats', 'teriyaki chicken'],
#  ['grilled chicken taquitos',
#   'alaskan salmon burgers',
#   'hass avocados',
#   'teriyaki chicken',
#   'brussels sprouts',
#   'seedless red grapes',
#   'apples'],
#  ['organic spring mix', 'teriyaki chicken', 'coconut water'],
#  ['boneless skinless chicken breasts', 'teriyaki chicken'],
#  ['fish nuggets',
#   'butter bread',
#   'organic vanilla almond milk',
#   'grilled chicken breast strips',
#   'organic iced green tea',
#   'roasted chicken & garlic rice pilaf mix',
#   'garlic & herb rice pilaf mix',
#   'organic strawberry yogurt & fruit snack',
#   'everything deli style pretzel crisps crackers',
#   'italian herbs & olive oil mozzarella stix',
#   'chicken fried rice',
#   'organic beef uncured hot dogs',
#   'organic strawberry lemonade',
#   'cranberry ginger kombucha',
#   'chicken breast tenders breaded',
#   'organic apple juice',
#   'four cheese thin crust pizza',
#   'thin crust pepperoni pizza',
#   'organic yukon select fries',
#   'light and lean 3 cheese penne marinara',
#   'gluten free garden vegetable lasagna',
#   'teriyaki chicken'],
#  ['teriyaki chicken'],
#  ['broccoli florettes',
#   '100% carrot juice',
#   'cauliflower florets',
#   'teriyaki chicken',
#   'organic chia seeds'],
#  ['clean care big roll toilet paper',
#   'real aged cheddar macaroni & cheese',
#   'white cheddar macaroni & cheese cups',
#   'potato original',
#   'indian aloo mattar wrap',
#   'teriyaki chicken'],
#  ['soda',
#   'zero calorie cola',
#   'teriyaki chicken',
#   'bag of organic bananas',
#   'chocolate wafers candy bar',
#   'original beef jerky',
#   'chocolate chip cookies',
#   'organic tortilla chips'],
#  ['teriyaki chicken', 'honeycrisp apples', 'graham crackers'],
#  ['organic whole milk', 'organic sour cream', 'teriyaki chicken'],
#  ['reduced fat 2% milk',
#   'grilled chicken strips',
#   'baked scalloped potatoes',
#   'shredded parmigiano reggiano',
#   'vanilla ice cream',
#   'classic roast',
#   'hamburger buns',
#   'beef dinner franks',
#   'teriyaki chicken',
#   'organic medium salsa'],
#  ['beef franks', 'teriyaki chicken', 'buffalo wings'],
#  ['small curd lowfat 2% milkfat cottage cheese',
#   'organic mustard',
#   'organic medium salsa',
#   'teriyaki chicken',
#   'bag of organic bananas',
#   'clementines'],
#  ['fresh mozzarella all-natural sliced cheese',
#   'premium sliced bacon',
#   'organic broccoli florets',
#   'teriyaki chicken',
#   'american pasteurized cheese slices',
#   'boneless pork shoulder butt'],
#  ['teriyaki chicken',
#   'usda aa extra large eggs',
#   'soda',
#   'organic tortilla chips',
#   'beef franks',
#   'non-scratch scrub sponges'],
#  ['organic 2% chocolate milk',
#   'teriyaki chicken',
#   'clementines',
#   'gold kiwi',
#   'spring water'],
#  ['teriyaki chicken', 'teriyaki & pineapple chicken meatballs'],
#  ['peppermint bark',
#   'soda',
#   'ice cream variety pack',
#   'drumsticks',
#   'teriyaki chicken',
#   'strawberries'],
#  ['hass avocados',
#   'rigatoni with chicken & pesto',
#   'santitas tortilla chips 14.5 oz',
#   'butter with olive oil & sea salt',
#   'organic yellow onion',
#   'chicken fried rice',
#   'teriyaki chicken',
#   'black pepper chicken',
#   'favorites alfredo pasta with chicken & broccoli',
#   'flour soft taco tortillas',
#   'cranberry juice',
#   'strawberries',
#   'sour cream',
#   'ground cumin'],
#  ['cola soda',
#   'original plain yoghurt',
#   'chicken thighs',
#   'original chocolate chip cookies',
#   'chips ahoy! chewy cookies',
#   'fresh ca grown eggs',
#   'lemonade',
#   'teriyaki chicken',
#   'pepperoni pizza for one',
#   'simple favorites chicken fettuccini frozen entree',
#   'breaded nuggets chicken breast',
#   'teriyaki marinade'],
#  ['fat free skim milk',
#   'liquid egg whites',
#   'cereal',
#   'roasted pine nut hummus',
#   'teriyaki chicken'],
#  ['steak strips',
#   'teriyaki chicken',
#   'reduced fat 2% milk',
#   'brioche hamburger buns',
#   'veggie cheese & pretzel snack pac prepacked',
#   'dried mangos'],
#  ['smoked pulled pork', 'teriyaki chicken']]

# %%
def get_batch(vocab, model, n_batches=3):
    output = list()
    for i in range(0, n_batches):
        rand_int = np.random.randint(len(vocab), size=1)[0]
        suggestions = model.simi(positive=[vocab[rand_int]], topn=5)
        suggest = list()
        for i in suggestions:
            suggest.append(i[0])
        output += suggest
        output.append(vocab[rand_int])
    return output

def plot_with_labels(low_dim_embs, labels, filename='tsne.png'):
    """From Tensorflow's tutorial."""
    assert low_dim_embs.shape[0] >= len(labels), "More labels than embeddings"
    plt.figure(figsize=(21, 21))  #in inches
    for i, label in enumerate(labels):
        x, y = low_dim_embs[i,:]
        plt.scatter(x, y)
        plt.annotate(label,
                     xy=(x, y),
                     xytext=(5, 2),
                     textcoords='offset points',
                     ha='right',
                     va='bottom')
    plt.show()

# %%
from matplotlib import pyplot as plt
embeds = []
labels = []
for item in get_batch(vocab, model, n_batches=5):
    embeds.append(pca.transform(model[item])[0])
    labels.append(products.loc[int(item)]['product_name'])
embeds = np.array(embeds)
plot_with_labels(embeds, labels)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [69], in <cell line: 4>()
#       2 embeds = []
#       3 labels = []
# ----> 4 for item in get_batch(vocab, model, n_batches=5):
#       5     embeds.append(pca.transform(model[item])[0])
#       6     labels.append(products.loc[int(item)]['product_name'])
#
# Input In [68], in get_batch(vocab, model, n_batches)
#       3 for i in range(0, n_batches):
#       4     rand_int = np.random.randint(len(vocab), size=1)[0]
# ----> 5     suggestions = model.most_similar(positive=[vocab[rand_int]], topn=5)
#       6     suggest = list()
#       7     for i in suggestions:
#
# AttributeError: 'Word2Vec' object has no attribute 'most_similar'

# %%
from gensim.test.utils import common_texts
from gensim.models import Phrases

# %%
# Train a bigram detector.
bigram_transformer = Phrases(common_texts)

# Apply the trained MWE detector to a corpus, using the result to train a Word2vec model.
# model = Word2Vec(bigram_transformer[common_texts], min_count=1)
